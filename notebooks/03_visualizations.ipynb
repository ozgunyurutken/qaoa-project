# %% [markdown]
# # Notebook 03 — Presentation figures
#
# Generates all 10 figures listed in brief Section 7 and saves each as PNG (dpi=300) + SVG under `results/figures/`.

# %% [markdown]
# ## Setup

# %%
import os, sys
from pathlib import Path
# Move CWD to the project root so relative paths (configs/, results/) work
# regardless of where the notebook is launched from.
_here = Path.cwd()
if _here.name == 'notebooks':
    os.chdir(_here.parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))
print('cwd:', Path.cwd())

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import pandas as pd

from src import visualizations as viz
from src.run_experiment import aggregate_results

viz.setup_style()

# Pre-compute the two shared datasets:
#   k3 — K₃ p=1 detailed run (for figures 01, 02, 03, 04, 10)
#   agg — aggregated scaling results (for figures 05, 06, 07, 08)
k3 = viz.collect_k3_detailed()
df = pd.read_json('results/data/scaling_results.json', orient='records')
agg = aggregate_results(df)
print('k3 ready, agg rows:', len(agg))

# %% [markdown]
# ## Figure 01 — K₃ QAOA circuit diagram

# %%
fig = viz.make_figure_01(k3)
paths = viz.save_fig(fig, '01_k3_circuit_diagram', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 02 — K₃ measurement histogram (after QAOA)

# %%
fig = viz.make_figure_02(k3)
paths = viz.save_fig(fig, '02_k3_measurement_histogram', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 03 — K₃ optimization curve (⟨H_C⟩ vs iteration)

# %%
fig = viz.make_figure_03(k3)
paths = viz.save_fig(fig, '03_k3_optimization_curve', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 04 — K₃ parameter landscape F(γ, β)

# %%
fig = viz.make_figure_04(k3)
paths = viz.save_fig(fig, '04_k3_parameter_landscape', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 05 — approximation ratio vs N (per p)

# %%
fig = viz.make_figure_05(agg)
paths = viz.save_fig(fig, '05_approximation_ratio_vs_n', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 06 — gate count vs N (total + CNOT, per p)

# %%
fig = viz.make_figure_06(agg)
paths = viz.save_fig(fig, '06_gate_count_vs_n', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 07 — circuit depth vs N (per p)

# %%
fig = viz.make_figure_07(agg)
paths = viz.save_fig(fig, '07_depth_vs_n', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 08 — approximation ratio vs p (selected N)

# %%
fig = viz.make_figure_08(agg)
paths = viz.save_fig(fig, '08_approximation_ratio_vs_p', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 09 — graph examples — K₃ + 3-regular N=6

# %%
fig = viz.make_figure_09()
paths = viz.save_fig(fig, '09_graph_examples', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Figure 10 — K₃ histogram — before vs after QAOA

# %%
fig = viz.make_figure_10(k3)
paths = viz.save_fig(fig, '10_histogram_comparison', 'results/figures')
plt.show()
print('saved:', paths)

# %% [markdown]
# ## Verify all 10 figures exist

# %%
expected = [
    '01_k3_circuit_diagram', '02_k3_measurement_histogram',
    '03_k3_optimization_curve', '04_k3_parameter_landscape',
    '05_approximation_ratio_vs_n', '06_gate_count_vs_n',
    '07_depth_vs_n', '08_approximation_ratio_vs_p',
    '09_graph_examples', '10_histogram_comparison',
]
missing = []
for stem in expected:
    for ext in ('png', 'svg'):
        p = Path('results/figures') / f'{stem}.{ext}'
        if not p.exists() or p.stat().st_size == 0:
            missing.append(str(p))

if missing:
    print('MISSING:', missing)
else:
    print(f'✓ all {len(expected)} figures saved as PNG + SVG')
assert not missing
